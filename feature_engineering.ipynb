# %%
# Data Loading

import numpy as np

metro_train_file_path = '/home/zhibo/data/hexi/hexi2/global_urban_computing/data/temp'
metro_train_data = pd.read_csv(metro_train_file_path+'/station_46.csv') 
metro_train_data.head()
# Out:
#              timestamp  inNums  outNums
# 0  2019-01-01 00:00:00       0        0
# 1  2019-01-01 00:10:00       0        0
# 2  2019-01-01 00:20:00       0        0
# 3  2019-01-01 00:30:00       0        0
# 4  2019-01-01 00:40:00       0        0

# %%
metro_train_data['is_holidy'] = metro_train_data['timestamp'].dt.dayofweek

# %%
metro_train_data['timestamp'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
metro_train_data['timestamp'].max()
# Out:
# Timestamp('2019-01-25 23:50:00')

# %%
import os
import pandas as pd
metro_train_file_path = '/home/zhibo/data/hexi/hexi2/global_urban_computing/data'

for i in range(82):
    metro_train_data = pd.read_csv(metro_train_file_path + '/temp/station_' + str(i) + '.csv') 
    metro_train_data['timestamp'] = pd.to_datetime(metro_train_data['timestamp'])
    metro_train_data['week_day'] = metro_train_data['timestamp'].dt.dayofweek
    metro_train_data['current_hour'] = metro_train_data['timestamp'].dt.hour
    metro_train_data[['lag_yesterday_in','lag_yesterday_out']] = metro_train_data[['inNums','outNums']].shift(periods=144).fillna(-1).astype(int)
    metro_train_data[['lay_last_week_in','lay_last_week_out']] = metro_train_data[['inNums','outNums']].shift(periods=144*7).fillna(-1).astype(int)
    metro_train_data.to_csv(metro_train_file_path + '/data_feature/st_' + str(i) + '.csv')

# %%
metro_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3600 entries, 0 to 3599
# Data columns (total 5 columns):
# timestamp       3600 non-null datetime64[ns]
# inNums          3600 non-null int64
# outNums         3600 non-null int64
# DayofWeek       3600 non-null int64
# current_hour    3600 non-null int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 140.7 KB

# %%
metro_train_data[(metro_train_data['timestamp'].dt.day==4) & (metro_train_data['timestamp'].dt.hour> 6)].head(5)
# Out:
#               timestamp  inNums  outNums  DayofWeek  current_hour  \
# 474 2019-01-04 07:00:00      95       54          4             7
# 475 2019-01-04 07:10:00     116       93          4             7
# 476 2019-01-04 07:20:00     158      102          4             7
# 477 2019-01-04 07:30:00     237      150          4             7
# 478 2019-01-04 07:40:00     259      219          4             7
#
#      lag_yesterday_in  lag_yesterday_out  lay_last_week_in  lay_last_week_out
# 474                98                 76                -1                 -1
# 475               102                110                -1                 -1
# 476               177                 93                -1                 -1
# 477               234                163                -1                 -1
# 478               245                230                -1                 -1

# %%
metro_train_data[(metro_train_data['timestamp'].dt.day==11) & (metro_train_data['timestamp'].dt.hour> 6)].head(5)
# Out:
#                timestamp  inNums  outNums  DayofWeek  current_hour  \
# 1482 2019-01-11 07:00:00      95       82          4             7
# 1483 2019-01-11 07:10:00     117       97          4             7
# 1484 2019-01-11 07:20:00     175       99          4             7
# 1485 2019-01-11 07:30:00     247      168          4             7
# 1486 2019-01-11 07:40:00     231      197          4             7
#
#       lag_yesterday_in  lag_yesterday_out  lay_last_week_in  lay_last_week_out
# 1482                79                 73                95                 54
# 1483               113                 75               116                 93
# 1484               163                120               158                102
# 1485               232                161               237                150
# 1486               254                222               259                219

# %%
metro_train_data[(metro_train_data['inNums']!=0) & (metro_train_data['timestamp'].dt.day>3)].head(20)
# Out:
#               timestamp  inNums  outNums  DayofWeek  current_hour  \
# 466 2019-01-04 05:40:00       3        2          4             5
# 467 2019-01-04 05:50:00       6        2          4             5
# 468 2019-01-04 06:00:00      16        3          4             6
# 469 2019-01-04 06:10:00      15       14          4             6
# 470 2019-01-04 06:20:00      21       24          4             6
# 471 2019-01-04 06:30:00      51       24          4             6
# 472 2019-01-04 06:40:00      48       43          4             6
# 473 2019-01-04 06:50:00      62       44          4             6
# 474 2019-01-04 07:00:00      95       54          4             7
# 475 2019-01-04 07:10:00     116       93          4             7
# 476 2019-01-04 07:20:00     158      102          4             7
# 477 2019-01-04 07:30:00     237      150          4             7
# 478 2019-01-04 07:40:00     259      219          4             7
# 479 2019-01-04 07:50:00     401      365          4             7
# 480 2019-01-04 08:00:00     491      534          4             8
# 481 2019-01-04 08:10:00     424      842          4             8
# 482 2019-01-04 08:20:00     388      712          4             8
# 483 2019-01-04 08:30:00     398      812          4             8
# 484 2019-01-04 08:40:00     366     1143          4             8
# 485 2019-01-04 08:50:00     263      964          4             8
#
#      lag_yesterday_in  lag_yesterday_out
# 466                 3                  0
# 467                 7                  4
# 468                13                  2
# 469                20                  3
# 470                32                 25
# 471                66                 40
# 472                49                 49
# 473                92                 79
# 474                98                 76
# 475               102                110
# 476               177                 93
# 477               234                163
# 478               245                230
# 479               397                278
# 480               482                500
# 481               455                760
# 482               404                720
# 483               413                853
# 484               331               1212
# 485               277                954

# %%
import os
[d for d in os.listdir('/home/zhibo/data/hexi/hexi2/global_urban_computing/data/temp')]
# Out:
# ['station_46.csv',
#  'station_52.csv',
#  'station_3.csv',
#  'station_70.csv',
#  'station_25.csv',
#  'station_41.csv',
#  'station_35.csv',
#  'station_75.csv',
#  'station_31.csv',
#  'station_59.csv',
#  'station_68.csv',
#  'station_19.csv',
#  'station_45.csv',
#  'station_51.csv',
#  'station_72.csv',
#  'station_56.csv',
#  'station_30.csv',
#  'station_49.csv',
#  'station_77.csv',
#  'station_67.csv',
#  'station_34.csv',
#  'station_42.csv',
#  'station_26.csv',
#  'station_64.csv',
#  'station_32.csv',
#  'station_9.csv',
#  'station_18.csv',
#  'station_2.csv',
#  'station_24.csv',
#  'station_48.csv',
#  'station_66.csv',
#  'station_76.csv',
#  'station_14.csv',
#  'station_53.csv',
#  'station_21.csv',
#  'station_40.csv',
#  'station_61.csv',
#  'station_1.csv',
#  'station_8.csv',
#  'station_62.csv',
#  'station_5.csv',
#  'station_71.csv',
#  'station_55.csv',
#  'station_33.csv',
#  'station_47.csv',
#  'station_28.csv',
#  'station_22.csv',
#  'station_57.csv',
#  'station_58.csv',
#  'station_50.csv',
#  'station_73.csv',
#  'station_17.csv',
#  'station_39.csv',
#  'station_36.csv',
#  'station_79.csv',
#  'station_11.csv',
#  'station_69.csv',
#  'station_54.csv',
#  'station_63.csv',
#  'station_13.csv',
#  'station_23.csv',
#  'station_15.csv',
#  'station_60.csv',
#  'station_0.csv',
#  'station_43.csv',
#  'station_65.csv',
#  'station_80.csv',
#  'station_10.csv',
#  'station_12.csv',
#  'station_44.csv',
#  'station_7.csv',
#  'station_38.csv',
#  'station_6.csv',
#  'station_20.csv',
#  'station_74.csv',
#  'station_37.csv',
#  'station_16.csv',
#  'station_27.csv',
#  'station_81.csv',
#  'station_4.csv',
#  'station_29.csv',
#  'station_78.csv']
